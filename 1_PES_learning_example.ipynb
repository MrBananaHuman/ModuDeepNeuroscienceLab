# %%
# !pip install nengo
# Out:
# Collecting nengo
#   Downloading https://files.pythonhosted.org/packages/d4/1a/a1fb5418f1656c2e630bac74088f6b084ec866a2890b7d0b36bbba850298/nengo-3.0.0-py3-none-any.whl (391kB)
#      |████████████████████████████████| 399kB 3.4MB/s
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.6/dist-packages (from nengo) (1.17.5)
# Installing collected packages: nengo
# Successfully installed nengo-3.0.0

# %% [markdown]
# input: white gaussian noise
#
# input -> bypass_synapse -> pre -> random synapse -> post

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
import nengo
from nengo.processes import WhiteSignal
from nengo.utils.matplotlib import rasterplot

# %%
model = nengo.Network()
with model:
    inp = nengo.Node(WhiteSignal(50, high=5), size_out=1)
    pre = nengo.Ensemble(50, dimensions=1)
    nengo.Connection(inp, pre)
    post = nengo.Ensemble(50, dimensions=1)
    conn = nengo.Connection(pre, post, function=lambda x: np.random.random(1))
    # random initialize synaptic weight
    inp_p = nengo.Probe(inp)
    pre_p = nengo.Probe(pre, synapse=0.01)      # synapse: filter the probed signal
    pre_spike_p = nengo.Probe(pre.neurons)
    post_p = nengo.Probe(post, synapse=0.01)
    post_spike_p = nengo.Probe(post.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(10.0)
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# <script>
#               (function () {
#                   var root = document.getElementById('fa144106-cb2d-4bc8-9bee-0a737741ef80');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# <script>
#               (function () {
#                   var root = document.getElementById('276b84fb-628c-4069-a33f-35ed6e3f3bab');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulation finished in 0:00:06.';
#
#             if (100.0 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '100.0%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>

# %%
plt.figure(figsize=(12, 4))
plt.plot(sim.trange(), sim.data[inp_p].T[0], c='k', label='Input')
plt.plot(sim.trange(), sim.data[pre_p].T[0], c='b', label='Pre')
plt.plot(sim.trange(), sim.data[post_p].T[0], c='r', label='Post')
plt.legend()

# %%
plt.figure(figsize=(12, 16))
plt.subplot(2, 1, 1)
rasterplot(sim.trange(), sim.data[pre_spike_p])
plt.xlabel('time [s]');
plt.subplot(2, 1, 2)
rasterplot(sim.trange(), sim.data[post_spike_p])
plt.xlabel('time [s]');

# %%
with model:
    inp = nengo.Node(WhiteSignal(50, high=5), size_out=1)
    pre = nengo.Ensemble(50, dimensions=1)
    nengo.Connection(inp, pre)
    post = nengo.Ensemble(50, dimensions=1)
    conn = nengo.Connection(pre, post, function=lambda x: np.random.random(1))

    error = nengo.Ensemble(50, dimensions=1)
    nengo.Connection(post, error)
    nengo.Connection(pre, error, transform=-1)

    conn.learning_rule_type = nengo.PES()
    nengo.Connection(error, conn.learning_rule)

    inp_p = nengo.Probe(inp)
    pre_p = nengo.Probe(pre, synapse=0.01)      # synapse: filter the probed signal
    pre_spike_p = nengo.Probe(pre.neurons)
    post_p = nengo.Probe(post, synapse=0.01)
    post_spike_p = nengo.Probe(post.neurons)
    error_p = nengo.Probe(error, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(10.0)
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# <script>
#               (function () {
#                   var root = document.getElementById('a1dd4b57-e74b-4a0a-a778-7a6bf9b3a615');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# <script>
#               (function () {
#                   var root = document.getElementById('10ae0ecd-902a-48cc-82fe-74511edd9c3c');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulation finished in 0:00:16.';
#
#             if (100.0 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '100.0%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>

# %%
plt.figure(figsize=(12, 4))
plt.plot(sim.trange(), sim.data[inp_p].T[0], c='k', label='Input')
plt.plot(sim.trange(), sim.data[pre_p].T[0], c='b', label='Pre')
plt.plot(sim.trange(), sim.data[post_p].T[0], c='r', label='Post')
plt.legend()
